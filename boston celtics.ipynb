# %%
import sys
from dotenv import load_dotenv
import os
import requests
import pandas as pd
import json

url = "https://api-nba-v1.p.rapidapi.com/players"

querystring = {"team":"2","season":"2021"}

headers = {
	"X-RapidAPI-Key": "57ecd31499mshfd9806745498469p111422jsnd51630f333ce",
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
response_celtics = response.json()
print(json.dumps(response_celtics, indent=4))
# Out:
# {
#     "get": "players/",
#     "parameters": {
#         "team": "2",
#         "season": "2021"
#     },
#     "errors": [],
#     "results": 41,
#     "response": [
#         {
#             "id": 362,
#             "firstname": "CJ",
#             "lastname": "Miles",
#             "birth": {
#                 "date": "1987-03-18",
#                 "country": "USA"
#             },
#             "nba": {
#                 "start": 2005,
#                 "pro": 0
#             },
#             "height": {
#                 "feets": null,
#                 "inches": null,
#                 "meters": null
#             },
#             "weight": {
#                 "pounds": null,
#                 "kilograms": null
#             },
#             "college": "No College",
#             "affiliation": "No College/USA",
#             "leagues": {
#                 "standard": {
#                     "jersey": 50,
#                     "active": false,
# ...

# %%
celtics_df = pd.json_normalize(response_celtics['response']).reset_index()
celtics_df
# Out:
#     index    id  firstname      lastname                              college  \
# 0       0   362         CJ         Miles                           No College
# 1       1   446       Josh    Richardson                            Tennessee
# 2       2    75     Jaylen         Brown                           California
# 3       3   597       Zach       Auguste                                 None
# 4       4   230    Juancho   Hernangomez                          Estudiantes
# 5       5   609       Ryan   Arcidiacono                            Villanova
# 6       6   882     Jayson         Tatum                                 Duke
# 7       7   806     Justin       Jackson                       North Carolina
# 8       8   897    Derrick         White                             Colorado
# 9       9   819       Luke        Kornet                           Vanderbilt
# 10     10   886     Daniel         Theis                        Brose Bamberg
# ...

# %%
celtics_df_csv = celtics_df.to_csv('Resources/Boston Celtics', index=False)
