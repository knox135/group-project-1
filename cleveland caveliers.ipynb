# %%
import sys
from dotenv import load_dotenv
import os
import requests
import pandas as pd
import time

# %%
load_dotenv()
load_dotenv('.env')
sports_data_api_key = os.getenv('SPORTS_DATA_API_KEY')

# %%
sports_data_api_key = os.getenv('SPORTS_DATA_API_KEY')

url = "https://api-nba-v1.p.rapidapi.com/players"

api_key_str = '?key='+sports_data_api_key

querystring = {"team":"7","season":"2023"}

headers = {
	"X-RapidAPI-Key": sports_data_api_key,
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response_cavs = response.json()

print(json.dumps(response_cavs, indent=4))
# Out:
# {
#     "get": "players/",
#     "parameters": {
#         "team": "7",
#         "season": "2023"
#     },
#     "errors": [],
#     "results": 21,
#     "response": [
#         {
#             "id": 281,
#             "firstname": "Damian",
#             "lastname": "Jones",
#             "birth": {
#                 "date": "1995-06-30",
#                 "country": "USA"
#             },
#             "nba": {
#                 "start": 2016,
#                 "pro": 5
#             },
#             "height": {
#                 "feets": "6",
#                 "inches": "11",
#                 "meters": "2.11"
#             },
#             "weight": {
#                 "pounds": "245",
#                 "kilograms": "111.1"
#             },
#             "college": "Vanderbilt",
#             "affiliation": "Vanderbilt/USA",
#             "leagues": {
#                 "standard": {
#                     "jersey": 30,
#                     "active": true,
# ...

# %%
cavs_df = pd.json_normalize(response_cavs['response']).reset_index(drop=True)
cavs_df
# Out:
#       id  firstname    lastname              college              affiliation  \
# 0    281     Damian       Jones           Vanderbilt           Vanderbilt/USA
# 1    317      Caris      LeVert             Michigan             Michigan/USA
# 2    391    Georges       Niang           Iowa State           Iowa State/USA
# 3    840    Donovan    Mitchell           Louisville           Louisville/USA
# 4    727    Jarrett       Allen                Texas                Texas/USA
# 5   1025     Zhaire       Smith           Texas Tech           Texas Tech/USA
# 6   2051        Max       Strus               DePaul               DePaul/USA
# 7   1860     Darius     Garland           Vanderbilt           Vanderbilt/USA
# 8   1870         Ty      Jerome             Virginia             Virginia/USA
# 9   2392       Dean        Wade         Kansas State         Kansas State/USA
# 10  2630      Isaac       Okoro               Auburn               Auburn/USA
# ...

# %%
cavs_df_csv = cavs_df.to_csv('Resources/Cleveland Caveliers.csv', index=False)

# %%
import time

data_frames = []

def get_player_stats(player_id):
    time.sleep(30)
    return pd.json_normalize(requests.get(url+"/statistics", headers=headers, params={"id":player_id, "season":"2023"}).json()['response'])

for id in cavs_df['id']:
    df = get_player_stats(id)
    data_frames.append(df)

combined_df = pd.concat(data_frames, ignore_index=True)
combined_df
# Out:
#       points pos min  fgm  fga    fgp  ftm  fta    ftp  tpm  ...  comment  \
# 0          8   C  20    4    4  100.0    0    4      0    0  ...     None
# 1          0   C  11    0    1      0    0    0      0    0  ...     None
# 2         11   C  21    2    2  100.0    7    7  100.0    0  ...     None
# 3          0   C   7    0    0      0    0    0      0    0  ...     None
# 4          4   C  11    2    2  100.0    0    0      0    0  ...     None
# ...      ...  ..  ..  ...  ...    ...  ...  ...    ...  ...  ...      ...
# 1025       2  SF  27    1    7   14.3    0    0      0    0  ...     None
# 1026       0  SF   7    0    0      0    0    0      0    0  ...     None
# 1027       3  SF   9    1    3   33.3    0    0      0    1  ...     None
# 1028       4  SF  16    2    4   50.0    0    0      0    0  ...     None
# 1029       0  SF   5    0    2      0    0    0      0    0  ...     None
#
#      player.id  player.firstname  player.lastname  team.id  \
# ...

# %%
cavs_stats = combined_df.to_csv('Resources/Stats Cleveland Cavaliers.csv', index=False)
