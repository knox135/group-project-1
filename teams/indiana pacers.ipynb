# %%
import sys
from dotenv import load_dotenv
import os
import requests
import pandas as pd
import json

# %%
load_dotenv()
load_dotenv('.env')
# Out:
# True

# %%
sports_data_api_key = os.getenv('SPORTS_DATA_API_KEY')
url = "https://api-nba-v1.p.rapidapi.com/players"
api_key_str = '?key='+sports_data_api_key
querystring = {"team":"15","season":"2023"}

headers = {
	"X-RapidAPI-Key": sports_data_api_key,
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
response_pacers = response.json()
print(json.dumps(response_pacers, indent=4))
# Out:
# {
#     "get": "players/",
#     "parameters": {
#         "team": "15",
#         "season": "2023"
#     },
#     "errors": [],
#     "results": 22,
#     "response": [
#         {
#             "id": 522,
#             "firstname": "Myles",
#             "lastname": "Turner",
#             "birth": {
#                 "date": "1996-03-24",
#                 "country": "USA"
#             },
#             "nba": {
#                 "start": 2015,
#                 "pro": 6
#             },
#             "height": {
#                 "feets": "6",
#                 "inches": "11",
#                 "meters": "2.11"
#             },
#             "weight": {
#                 "pounds": "250",
#                 "kilograms": "113.4"
#             },
#             "college": "Texas",
#             "affiliation": "Texas/USA",
#             "leagues": {
#                 "standard": {
#                     "jersey": 33,
#                     "active": true,
# ...

# %%
pacers_df = pd.json_normalize(response_pacers['response']).reset_index(drop=True)
pacers_df
# Out:
#       id  firstname    lastname           college                affiliation  \
# 0    522      Myles      Turner             Texas                  Texas/USA
# 1    236      Buddy       Hield          Oklahoma           Oklahoma/Bahamas
# 2    479     Pascal      Siakam  New Mexico State  New Mexico State/Cameroon
# 3    886     Daniel       Theis     Brose Bamberg      Brose Bamberg/Germany
# 4    944      Bruce       Brown             Miami                  Miami/USA
# 5   3476     Andrew    Nembhard              None                       None
# 6   2628     Jordan       Nwora        Louisville             Louisville/USA
# 7   2658        Obi      Toppin            Dayton                 Dayton/USA
# 8   2595     Tyrese  Haliburton        Iowa State             Iowa State/USA
# 9   2626      Aaron     Nesmith        Vanderbilt             Vanderbilt/USA
# 10  2644      Jalen       Smith          Maryland               Maryland/USA
# ...

# %%
pacers_df_csv = pacers_df.to_csv('Resources/Indiana Pacers.csv', index=False)

# %%
import time

data_frames = []

def get_player_stats(player_id):
    time.sleep(30)
    return pd.json_normalize(requests.get(url+"/statistics", headers=headers, params={"id":player_id, "season":"2023"}).json()['response'])

for id in pacers_df['id']:
    df = get_player_stats(id)
    data_frames.append(df)

combined_df = pd.concat(data_frames, ignore_index=True)
combined_df

# %%
pacers_stats = combined_df.to_csv('Resources/Stats Indiana Pacers.csv', index=False)
