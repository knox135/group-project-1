# %%
# !pip install prophet

# %%
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline

# %%
# Load all the files into dataframes and into a list
years = ["2018", "2019", "2020", "2021", "2022", "2023"]
standings_dataframes = []

for year in years:
    standings_dataframes.append(pd.read_csv(f"./Resources/{year} Standings.csv"))

#standings_dataframes[0].columns
all_standings_df = pd.concat(standings_dataframes, ignore_index=True)
display(all_standings_df.head())
display(all_standings_df.tail())
# Out:
#      league  season  gamesBehind  streak  winStreak  tieBreakerPoints  \
# 0  standard    2021         18.0       3      False               NaN
# 1  standard    2021         10.0       3       True               NaN
# 2  standard    2021          0.0       1      False               NaN
# 3  standard    2021         10.0       1       True               NaN
# 4  standard    2021         31.0       1       True               NaN
#
#    team.id           team.name team.nickname team.code  ... win.home win.away  \
# 0       41  Washington Wizards       Wizards       WAS  ...       21       14
# 1        5   Charlotte Hornets       Hornets       CHA  ...       22       21
# 2       20          Miami Heat          Heat       MIA  ...       29       24
# 3        1       Atlanta Hawks         Hawks       ATL  ...       27       16
# 4       26       Orlando Magic         Magic       ORL  ...       12       10
#
# ...
